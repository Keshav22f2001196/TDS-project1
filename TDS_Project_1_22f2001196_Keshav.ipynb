# %% [markdown]
# **Generate Git Hub Token**

# %%
# Replace YOUR_GITHUB_TOKEN_HERE with the actual token you generated
# %env GITHUB_TOKEN=
# Out:
# env: GITHUB_TOKEN=

# %%
import os

# Fetch the GitHub token from environment variables
GITHUB_TOKEN = os.getenv('GITHUB_TOKEN')

# Verify if the token is loaded correctly (optional)
if not GITHUB_TOKEN:
    raise ValueError("GitHub token not found. Please set the GITHUB_TOKEN environment variable.")
else:
    print("GitHub token is loaded.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-cf5404da9ec0> in <cell line: 7>()
#       6 # Verify if the token is loaded correctly (optional)
#       7 if not GITHUB_TOKEN:
# ----> 8     raise ValueError("GitHub token not found. Please set the GITHUB_TOKEN environment variable.")
#       9 else:
#      10     print("GitHub token is loaded.")
#
# ValueError: GitHub token not found. Please set the GITHUB_TOKEN environment variable.

# %%
import requests
import pandas as pd
import os
import time

# Fetch the GitHub token from environment variables
GITHUB_TOKEN = os.getenv('GITHUB_TOKEN')

if not GITHUB_TOKEN:
    raise ValueError("GitHub token not found. Set the GITHUB_TOKEN environment variable.")

HEADERS = {'Authorization': f'token {GITHUB_TOKEN}'}
USER_SEARCH_URL = 'https://api.github.com/search/users'
REPO_URL_TEMPLATE = 'https://api.github.com/users/{}/repos'

# Function to fetch all users in Dublin with over 50 followers, handling pagination
def get_users_in_dublin(min_followers=50):
    """
    Fetch GitHub users in Dublin with more than the specified number of followers,
    handling pagination to retrieve up to 500 users.
    """
    users = []
    params = {
        'q': f'location:Dublin followers:>{min_followers}',
        'per_page': 100,
        'page': 1
    }

    while True:
        response = requests.get(USER_SEARCH_URL, headers=HEADERS, params=params)

        if response.status_code != 200:
            print(f"Error: {response.status_code} - {response.json().get('message', 'Unknown error')}")
            break

        user_data = response.json()
        items = user_data.get('items', [])

        if not items:
            break

        for user in items:
            user_detail = requests.get(user['url'], headers=HEADERS).json()
            users.append({
                'login': user_detail.get('login', ''),
                'name': user_detail.get('name', ''),
                'company': user_detail.get('company', '').strip('@ ').upper() if user_detail.get('company') else '',
                'location': user_detail.get('location', ''),
                'email': user_detail.get('email', ''),
                'hireable': str(user_detail.get('hireable', False)).lower(),
                'bio': user_detail.get('bio', ''),
                'public_repos': user_detail.get('public_repos', 0),
                'followers': user_detail.get('followers', 0),
                'following': user_detail.get('following', 0),
                'created_at': user_detail.get('created_at', '')
            })

        params['page'] += 1
        print(f"Page {params['page'] - 1} fetched, total users so far: {len(users)}")
        time.sleep(1)

    return users

# Function to fetch all repositories for each user, with no limit
def get_repositories(user_logins):
    """
    Fetch all repositories for each user, handling pagination to retrieve every available repository.
    """
    repos = []
    for login in user_logins:
        page = 1
        while True:
            repo_url = f"{REPO_URL_TEMPLATE.format(login)}?per_page=100&page={page}"
            response = requests.get(repo_url, headers=HEADERS)

            if response.status_code != 200:
                print(f"Error fetching repositories for {login}: {response.status_code}")
                break

            user_repos = response.json()

            if not user_repos:
                break

            for repo in user_repos:
                license_info = repo.get('license')
                license_name = license_info.get('key', '') if license_info else ''

                repos.append({
                    'login': login,
                    'full_name': repo.get('full_name', ''),
                    'created_at': repo.get('created_at', ''),
                    'stargazers_count': repo.get('stargazers_count', 0),
                    'watchers_count': repo.get('watchers_count', 0),
                    'language': repo.get('language', ''),
                    'has_projects': str(repo.get('has_projects', False)).lower(),
                    'has_wiki': str(repo.get('has_wiki', False)).lower(),
                    'license_name': license_name
                })

            page += 1
            print(f"Page {page} of repositories for {login} fetched.")
            time.sleep(1)

    return repos

# Main function to execute both user and repository data fetching and saving to CSV
def main():
    # Step 1: Fetch all users in Dublin with over 50 followers
    print("Fetching users in Dublin with over 50 followers...")
    users = get_users_in_dublin()
    user_logins = [user['login'] for user in users]

    # Step 2: Fetch repositories for each user
    print("Fetching repositories for each user...")
    repos = get_repositories(user_logins)

    # Step 3: Save user data to users.csv
    users_df = pd.DataFrame(users)
    users_df.to_csv('users.csv', index=False)
    print("User data saved to users.csv")

    # Step 4: Save repository data to repositories.csv
    repos_df = pd.DataFrame(repos)
    repos_df.to_csv('repositories.csv', index=False)
    print("Repository data saved to repositories.csv")

if __name__ == '__main__':
    main()
# Out:
# Fetching users in Dublin with over 50 followers...
# Page 1 fetched, total users so far: 100
# Page 2 fetched, total users so far: 200
# Page 3 fetched, total users so far: 300
# Page 4 fetched, total users so far: 400
# Page 5 fetched, total users so far: 477
# Fetching repositories for each user...
# Page 2 of repositories for orta fetched.
# Page 3 of repositories for orta fetched.
# Page 4 of repositories for orta fetched.
# Page 5 of repositories for orta fetched.
# Page 6 of repositories for orta fetched.
# Page 7 of repositories for orta fetched.
# Page 8 of repositories for orta fetched.
# Page 9 of repositories for orta fetched.
# Page 10 of repositories for orta fetched.
# Page 11 of repositories for orta fetched.
# Page 2 of repositories for jeromeetienne fetched.
# Page 3 of repositories for jeromeetienne fetched.
# Page 4 of repositories for jeromeetienne fetched.
# Page 5 of repositories for jeromeetienne fetched.
# Page 2 of repositories for jonataslaw fetched.
# Page 3 of repositories for jonataslaw fetched.
# Page 4 of repositories for jonataslaw fetched.
# Page 2 of repositories for steventroughtonsmith fetched.
# Page 2 of repositories for axic fetched.
# Page 3 of repositories for axic fetched.
# Page 2 of repositories for lmammino fetched.
# Page 3 of repositories for lmammino fetched.
# Page 4 of repositories for lmammino fetched.
# Page 5 of repositories for lmammino fetched.
# Page 2 of repositories for flaviohenriquealmeida fetched.
# Page 2 of repositories for snrazavi fetched.
# Page 2 of repositories for filipesilva fetched.
# Page 2 of repositories for afshinm fetched.
# Page 3 of repositories for afshinm fetched.
# Page 2 of repositories for bl4de fetched.
# Page 2 of repositories for guibranco fetched.
# Page 2 of repositories for zalando fetched.
# Page 2 of repositories for avidLearnerInProgress fetched.
# Page 3 of repositories for avidLearnerInProgress fetched.
# Page 2 of repositories for derekmolloy fetched.
# Page 2 of repositories for AnikSarker fetched.
# Page 2 of repositories for clarkdo fetched.
# Page 2 of repositories for flaviojmendes fetched.
# Page 2 of repositories for wix fetched.
# Page 2 of repositories for ahmedadeltito fetched.
# Page 2 of repositories for xiaokangwang fetched.
# Page 3 of repositories for xiaokangwang fetched.
# Page 2 of repositories for Gpzim98 fetched.
# Page 2 of repositories for kracekumar fetched.
# Page 3 of repositories for kracekumar fetched.
# Page 2 of repositories for rampatra fetched.
# Page 2 of repositories for sadlil fetched.
# Page 2 of repositories for juarezpaf fetched.
# Page 2 of repositories for hmikihth fetched.
# Page 3 of repositories for hmikihth fetched.
# Page 4 of repositories for hmikihth fetched.
# Page 2 of repositories for imandyie fetched.
# Page 2 of repositories for rougeth fetched.
# Page 2 of repositories for masbahnana fetched.
# Page 2 of repositories for awesomeAB fetched.
# Page 2 of repositories for ppamorim fetched.
# Page 3 of repositories for ppamorim fetched.
# Page 4 of repositories for ppamorim fetched.
# Page 5 of repositories for ppamorim fetched.
# Page 2 of repositories for timmyomahony fetched.
# Page 2 of repositories for mina1460 fetched.
# Page 2 of repositories for igorbrigadir fetched.
# Page 3 of repositories for igorbrigadir fetched.
# Page 2 of repositories for 12Knocksinna fetched.
# Page 2 of repositories for mcspronko fetched.
# Page 2 of repositories for maK- fetched.
# Page 2 of repositories for soub4i fetched.
# Page 3 of repositories for soub4i fetched.
# Page 2 of repositories for goenning fetched.
# Page 3 of repositories for goenning fetched.
# Page 2 of repositories for LotteMakesStuff fetched.
# Page 2 of repositories for rafadelnero fetched.
# Page 2 of repositories for Rocketknight1 fetched.
# Page 2 of repositories for mdibaiee fetched.
# Page 3 of repositories for mdibaiee fetched.
# Page 2 of repositories for urschrei fetched.
# Page 3 of repositories for urschrei fetched.
# Page 2 of repositories for nsomar fetched.
# Page 2 of repositories for sipsorcery fetched.
# Page 2 of repositories for gabrielschade fetched.
# Page 2 of repositories for ZorinOS fetched.
# Page 2 of repositories for The-AI-Summer fetched.
# Page 2 of repositories for gokselkoksal fetched.
# Page 2 of repositories for mariocasciaro fetched.
# Page 2 of repositories for markdregan fetched.
# Page 2 of repositories for capnramses fetched.
# Page 2 of repositories for rxluz fetched.
# Page 2 of repositories for rbanffy fetched.
# Page 2 of repositories for boramalper fetched.
# Page 2 of repositories for gupta-utkarsh fetched.
# Page 2 of repositories for HouzuoGuo fetched.
# Page 2 of repositories for mesta1 fetched.
# Page 2 of repositories for greymd fetched.
# Page 2 of repositories for godcrampy fetched.
# Page 2 of repositories for mihaitodor fetched.
# Page 2 of repositories for theWhiteFox fetched.
# Page 3 of repositories for theWhiteFox fetched.
# Page 4 of repositories for theWhiteFox fetched.
# Page 2 of repositories for benmcmahon100 fetched.
# Page 2 of repositories for dmnfarrell fetched.
# Page 2 of repositories for ciaramcguire fetched.
# Page 2 of repositories for gchp fetched.
# Page 2 of repositories for abdelazeem201 fetched.
# Page 3 of repositories for abdelazeem201 fetched.
# Page 2 of repositories for lxsameer fetched.
# Page 2 of repositories for mehmetkose fetched.
# Page 3 of repositories for mehmetkose fetched.
# Page 2 of repositories for amir fetched.
# Page 2 of repositories for paulca fetched.
# Page 3 of repositories for paulca fetched.
# Page 2 of repositories for syxanash fetched.
# Page 2 of repositories for mikebrady fetched.
# Page 2 of repositories for AemieJ fetched.
# Page 2 of repositories for rangav fetched.
# Page 2 of repositories for kriscfoster fetched.
# Page 2 of repositories for intercom fetched.
# Page 3 of repositories for intercom fetched.
# Page 2 of repositories for lechien73 fetched.
# Page 3 of repositories for lechien73 fetched.
# Page 2 of repositories for cesanta fetched.
# Page 2 of repositories for mattdonnelly fetched.
# Page 2 of repositories for 5agado fetched.
# Page 2 of repositories for GavinJoyce fetched.
# Page 3 of repositories for GavinJoyce fetched.
# Page 2 of repositories for apssouza22 fetched.
# Page 2 of repositories for NayeonKeum fetched.
# Page 2 of repositories for No9 fetched.
# Page 3 of repositories for No9 fetched.
# Page 4 of repositories for No9 fetched.
# Page 5 of repositories for No9 fetched.
# Page 2 of repositories for marekdano fetched.
# Page 3 of repositories for marekdano fetched.
# Page 2 of repositories for Flavien fetched.
# Page 2 of repositories for dgonzalez fetched.
# Page 2 of repositories for aldanor fetched.
# Page 3 of repositories for aldanor fetched.
# Page 2 of repositories for carlosfilhou fetched.
# Page 2 of repositories for DamnWidget fetched.
# Page 2 of repositories for kassio fetched.
# Page 2 of repositories for kevinheavey fetched.
# Page 2 of repositories for pallotron fetched.
# Page 2 of repositories for DarthGandalf fetched.
# Page 3 of repositories for DarthGandalf fetched.
# Page 2 of repositories for esteedqueen fetched.
# Page 2 of repositories for thiagokokada fetched.
# Page 2 of repositories for colmdoyle fetched.
# Page 2 of repositories for stephenc fetched.
# Page 3 of repositories for stephenc fetched.
# Page 4 of repositories for stephenc fetched.
# Page 2 of repositories for mehdime fetched.
# Page 2 of repositories for kerimdzhanov fetched.
# Page 2 of repositories for aliva fetched.
# Page 2 of repositories for rojer fetched.
# Page 2 of repositories for coderick14 fetched.
# Page 2 of repositories for donovanh fetched.
# Page 3 of repositories for donovanh fetched.
# Page 2 of repositories for satori fetched.
# Page 2 of repositories for Pamir fetched.
# Page 3 of repositories for Pamir fetched.
# Page 4 of repositories for Pamir fetched.
# Page 2 of repositories for paskal fetched.
# Page 2 of repositories for raonyguimaraes fetched.
# Page 3 of repositories for raonyguimaraes fetched.
# Page 4 of repositories for raonyguimaraes fetched.
# Page 5 of repositories for raonyguimaraes fetched.
# Page 6 of repositories for raonyguimaraes fetched.
# Page 7 of repositories for raonyguimaraes fetched.
# Page 8 of repositories for raonyguimaraes fetched.
# Page 2 of repositories for caquino fetched.
# Page 2 of repositories for maxday fetched.
# Page 3 of repositories for maxday fetched.
# Page 2 of repositories for BDQ fetched.
# Page 2 of repositories for SaM-92 fetched.
# Page 2 of repositories for deathowl fetched.
# Page 3 of repositories for deathowl fetched.
# Page 2 of repositories for morganmcg1 fetched.
# Page 2 of repositories for cassiomolin fetched.
# Page 2 of repositories for tsee fetched.
# Page 3 of repositories for tsee fetched.
# Page 2 of repositories for adastreamer fetched.
# Page 2 of repositories for Chippd fetched.
# Page 2 of repositories for ymoslem fetched.
# Page 2 of repositories for ttroy50 fetched.
# Page 2 of repositories for sivaschenko fetched.
# Page 2 of repositories for zalando-incubator fetched.
# Page 2 of repositories for relistan fetched.
# Page 2 of repositories for andrewcparnell fetched.
# Page 2 of repositories for bartelink fetched.
# Page 2 of repositories for eddieantonio fetched.
# Page 3 of repositories for eddieantonio fetched.
# Page 4 of repositories for eddieantonio fetched.
# Page 2 of repositories for Barqawiz fetched.
# Page 2 of repositories for ankitrohatgi fetched.
# Page 2 of repositories for plattysoft fetched.
# Page 2 of repositories for nhtlongcs fetched.
# Page 2 of repositories for barreeeiroo fetched.
# Page 2 of repositories for cathalmccabe fetched.
# Page 2 of repositories for MosesEsan fetched.
# Page 2 of repositories for lucasas fetched.
# Page 2 of repositories for gohabereg fetched.
# Page 2 of repositories for NiallJoeMaher fetched.
# Page 2 of repositories for isabellasouzas fetched.
# Page 2 of repositories for Rita-Okonkwo fetched.
# Page 2 of repositories for eugeneius fetched.
# Page 2 of repositories for niqdev fetched.
# Page 2 of repositories for bakszero fetched.
# Page 2 of repositories for AdrianRossouw fetched.
# Page 2 of repositories for arashm fetched.
# Page 2 of repositories for aviraldg fetched.
# Page 2 of repositories for samueloph fetched.
# Page 2 of repositories for chrishokamp fetched.
# Page 2 of repositories for YoungForest fetched.
# Page 2 of repositories for adamisntdead fetched.
# Page 2 of repositories for MatissJanis fetched.
# Page 2 of repositories for julia-finassi fetched.
# Page 2 of repositories for bact fetched.
# Page 2 of repositories for dionarodrigues fetched.
# Page 2 of repositories for mrdavidlaing fetched.
# Page 3 of repositories for mrdavidlaing fetched.
# Page 2 of repositories for ebowman fetched.
# Page 2 of repositories for barnex fetched.
# Page 2 of repositories for ericm fetched.
# Page 2 of repositories for kiall fetched.
# Page 3 of repositories for kiall fetched.
# Page 2 of repositories for victor-cody fetched.
# Page 2 of repositories for jalalazimi fetched.
# Page 2 of repositories for shaneosullivan fetched.
# Page 2 of repositories for dreamos82 fetched.
# Page 2 of repositories for brk3 fetched.
# Page 3 of repositories for brk3 fetched.
# Page 2 of repositories for josmas fetched.
# Page 3 of repositories for josmas fetched.
# Page 2 of repositories for arthurbdiniz fetched.
# Page 2 of repositories for marlonbernardes fetched.
# Page 2 of repositories for adityastic fetched.
# Page 3 of repositories for adityastic fetched.
# Page 2 of repositories for Badhansen fetched.
# Page 3 of repositories for Badhansen fetched.
# Page 2 of repositories for JuniorTorresMTJ fetched.
# Page 2 of repositories for lkhphuc fetched.
# Page 2 of repositories for rcarriga fetched.
# Page 2 of repositories for idontknowjs fetched.
# Page 2 of repositories for lyuchenyang fetched.
# Page 2 of repositories for devinvestidor fetched.
# Page 2 of repositories for Ziggoto fetched.
# Page 2 of repositories for nating fetched.
# Page 2 of repositories for elisemercury fetched.
# Page 2 of repositories for efazati fetched.
# Page 2 of repositories for JonHanna fetched.
# Page 2 of repositories for darth30joker fetched.
# Page 2 of repositories for mspronesti fetched.
# Page 2 of repositories for Albert-W fetched.
# Page 2 of repositories for felipemeriga fetched.
# Page 2 of repositories for eduardolbruno fetched.
# Page 2 of repositories for oguzhane fetched.
# Page 2 of repositories for johnmcclean fetched.
# Page 2 of repositories for henrym2 fetched.
# Page 2 of repositories for qudongfang fetched.
# Page 2 of repositories for theycallmemac fetched.
# Page 2 of repositories for MathieuBuisson fetched.
# Page 2 of repositories for roddhjav fetched.
# Page 2 of repositories for rohantaneja fetched.
# Page 2 of repositories for invizbox fetched.
# Page 2 of repositories for SibeeshVenu fetched.
# Page 2 of repositories for luizgrp fetched.
# Page 2 of repositories for joshuacassidy fetched.
# Page 3 of repositories for joshuacassidy fetched.
# Page 4 of repositories for joshuacassidy fetched.
# Page 2 of repositories for claudinecallaghan fetched.
# Page 2 of repositories for dhruvarora fetched.
# Page 2 of repositories for tranlenam fetched.
# Page 2 of repositories for kieranjol fetched.
# Page 2 of repositories for Thrifleganger fetched.
# Page 2 of repositories for SeanDuggan fetched.
# Page 2 of repositories for AndrewLJackson fetched.
# Page 2 of repositories for Saegusae fetched.
# Page 2 of repositories for ByFishh fetched.
# Page 2 of repositories for stephen-howell fetched.
# Page 2 of repositories for manab-kb fetched.
# Page 2 of repositories for HoseinEmrani fetched.
# Page 2 of repositories for kaybenleroll fetched.
# Page 2 of repositories for jerry-shao fetched.
# Page 2 of repositories for Mongey fetched.
# Page 3 of repositories for Mongey fetched.
# Page 2 of repositories for ocanty fetched.
# Page 2 of repositories for MayconCardoso fetched.
# Page 2 of repositories for manfromanotherland fetched.
# Page 2 of repositories for siscia fetched.
# Page 3 of repositories for siscia fetched.
# Page 2 of repositories for nebkat fetched.
# Page 2 of repositories for marete fetched.
# Page 2 of repositories for sakrist fetched.
# Page 2 of repositories for johnglover fetched.
# Page 2 of repositories for carloscarvallo fetched.
# Page 2 of repositories for wjgilmore fetched.
# Page 2 of repositories for kaylode fetched.
# Page 2 of repositories for hamedrnik fetched.
# Page 2 of repositories for Chinmayrane16 fetched.
# Page 2 of repositories for jaswdr fetched.
# Page 2 of repositories for tombee fetched.
# Page 2 of repositories for daveearley fetched.
# Page 2 of repositories for Guray00 fetched.
# Page 2 of repositories for ezavile fetched.
# Page 2 of repositories for rpairo fetched.
# Page 2 of repositories for markdeegan fetched.
# Page 2 of repositories for evandroflores fetched.
# Page 2 of repositories for dehora fetched.
# Page 2 of repositories for rorhug fetched.
# Page 2 of repositories for dominykas fetched.
# Page 3 of repositories for dominykas fetched.
# Page 2 of repositories for jordimontana82 fetched.
# Page 2 of repositories for xaionaro fetched.
# Page 3 of repositories for xaionaro fetched.
# Page 2 of repositories for mcguinlu fetched.
# Page 2 of repositories for Mevrael fetched.
# Page 2 of repositories for andrewm4894 fetched.
# Page 3 of repositories for andrewm4894 fetched.
# Page 2 of repositories for gilliganondata fetched.
# Page 2 of repositories for mushketyk fetched.
# Page 2 of repositories for RonanKMcGovern fetched.
# Page 2 of repositories for PaulinaCzarnota fetched.
# Page 2 of repositories for kishoreyekkanti fetched.
# Page 2 of repositories for jasonrogena fetched.
# Page 2 of repositories for ruben1 fetched.
# Page 2 of repositories for krinkinmu fetched.
# Page 2 of repositories for SemanticallyNull fetched.
# Page 2 of repositories for bctnry fetched.
# Page 3 of repositories for bctnry fetched.
# Page 2 of repositories for EfeBudak fetched.
# Page 2 of repositories for itsmunim fetched.
# Page 2 of repositories for laserbat fetched.
# Page 2 of repositories for hasangenc0 fetched.
# Page 2 of repositories for Eroui fetched.
# Page 2 of repositories for conorosully fetched.
# Page 2 of repositories for butlerx fetched.
# Page 2 of repositories for rajitbanerjee fetched.
# Page 2 of repositories for martinmicunda fetched.
# Page 2 of repositories for ajami1331 fetched.
# Page 3 of repositories for ajami1331 fetched.
# Page 2 of repositories for sheeehy fetched.
# Page 2 of repositories for DzyubSpirit fetched.
# Page 3 of repositories for DzyubSpirit fetched.
# Page 2 of repositories for amineremache fetched.
# Page 2 of repositories for gcacace fetched.
# Page 2 of repositories for fermoya fetched.
# Page 2 of repositories for loyannec fetched.
# Page 2 of repositories for nosmo fetched.
# Page 2 of repositories for varol fetched.
# Page 2 of repositories for thesimplekid fetched.
# Page 2 of repositories for sberyozkin fetched.
# Page 2 of repositories for pshirshov fetched.
# Page 3 of repositories for pshirshov fetched.
# Page 2 of repositories for Mparaiso fetched.
# Page 2 of repositories for micaleel fetched.
# Page 2 of repositories for VitorNoVictor fetched.
# Page 2 of repositories for MKGAURAB fetched.
# Page 2 of repositories for AlexGascon fetched.
# Page 2 of repositories for johndharrison fetched.
# Page 2 of repositories for williamkennedy fetched.
# Page 2 of repositories for kgaughan fetched.
# Page 2 of repositories for Ruubia fetched.
# Page 2 of repositories for JamesCrook fetched.
# Page 2 of repositories for atopuzov fetched.
# Page 3 of repositories for atopuzov fetched.
# Page 2 of repositories for Hildebrando-Viana-Matos fetched.
# Page 2 of repositories for Soumyabrata fetched.
# Page 2 of repositories for vially fetched.
# Page 2 of repositories for mguilhermetavares fetched.
# Page 2 of repositories for ismagom fetched.
# Page 2 of repositories for johnbrett fetched.
# Page 2 of repositories for DubiousCactus fetched.
# Page 2 of repositories for jakekgrog fetched.
# Page 2 of repositories for drewfurgiuele fetched.
# Page 2 of repositories for jeethu fetched.
# Page 2 of repositories for Szer fetched.
# Page 2 of repositories for DaniJG fetched.
# Page 2 of repositories for FintanH fetched.
# Page 3 of repositories for FintanH fetched.
# Page 2 of repositories for dmitriz fetched.
# Page 3 of repositories for dmitriz fetched.
# Page 4 of repositories for dmitriz fetched.
# Page 5 of repositories for dmitriz fetched.
# Page 2 of repositories for tommymaher15 fetched.
# Page 2 of repositories for ciaranha fetched.
# Page 2 of repositories for braz fetched.
# Page 2 of repositories for yumin-chen fetched.
# Page 2 of repositories for oisin fetched.
# Page 2 of repositories for lalitkale fetched.
# Page 2 of repositories for lucabrunox fetched.
# Page 2 of repositories for alexisInSAR fetched.
# Page 2 of repositories for inversify fetched.
# Page 2 of repositories for heberop fetched.
# Page 2 of repositories for johnpaulhayes fetched.
# Page 2 of repositories for retecata fetched.
# Page 2 of repositories for aweimeow fetched.
# Page 2 of repositories for giacomorebonato fetched.
# Page 3 of repositories for giacomorebonato fetched.
# Page 2 of repositories for AgentMC fetched.
# Page 2 of repositories for rafaelcamaram fetched.
# Page 2 of repositories for Barros42 fetched.
# Page 2 of repositories for dethi fetched.
# Page 2 of repositories for reachanihere fetched.
# Page 2 of repositories for AnthonyBloomer fetched.
# Page 2 of repositories for yoniLavi fetched.
# Page 3 of repositories for yoniLavi fetched.
# Page 2 of repositories for aaman007 fetched.
# Page 3 of repositories for aaman007 fetched.
# Page 2 of repositories for Th3T3chn0G1t fetched.
# Page 2 of repositories for gordonknoppe fetched.
# Page 2 of repositories for chaosmail fetched.
# Page 2 of repositories for BrunoRosendo fetched.
# Page 2 of repositories for bergerx fetched.
# Page 2 of repositories for daishisystems fetched.
# Page 2 of repositories for dineshrathee12 fetched.
# Page 3 of repositories for dineshrathee12 fetched.
# Page 2 of repositories for hmleal fetched.
# Page 2 of repositories for laisbsc fetched.
# Page 2 of repositories for SkypLabs fetched.
# Page 2 of repositories for tmaher fetched.
# Page 2 of repositories for sachsom95 fetched.
# Page 2 of repositories for MarkPKCollier fetched.
# Page 2 of repositories for samukasmk fetched.
# Page 3 of repositories for samukasmk fetched.
# Page 2 of repositories for EffinMaggie fetched.
# Page 2 of repositories for diegocard fetched.
# Page 2 of repositories for hennasingh fetched.
# Page 3 of repositories for hennasingh fetched.
# Page 2 of repositories for wlepinski fetched.
# Page 2 of repositories for Margatroid fetched.
# Page 2 of repositories for barambani fetched.
# Page 3 of repositories for barambani fetched.
# Page 2 of repositories for dee-see fetched.
# Page 2 of repositories for davidino fetched.
# Page 2 of repositories for ArtyomZorin fetched.
# Page 2 of repositories for ruidfigueiredo fetched.
# Page 2 of repositories for crivetimihai fetched.
# Page 3 of repositories for crivetimihai fetched.
# Page 2 of repositories for PiotrJustyna fetched.
# Page 2 of repositories for kuzznya fetched.
# Page 2 of repositories for apontejaj fetched.
# Page 2 of repositories for ketanbhatt fetched.
# Page 2 of repositories for kudos fetched.
# Page 2 of repositories for conr fetched.
# Page 2 of repositories for brunoric fetched.
# Page 2 of repositories for infinity4471 fetched.
# Page 2 of repositories for stefan-mueller fetched.
# Page 2 of repositories for tomwillfixit fetched.
# Page 2 of repositories for SiddheshBangar fetched.
# Page 2 of repositories for ramdesh fetched.
# Page 2 of repositories for jonwk fetched.
# Page 2 of repositories for dtuite fetched.
# Page 2 of repositories for coogie fetched.
# Page 2 of repositories for wafuwafu13 fetched.
# Page 3 of repositories for wafuwafu13 fetched.
# Page 4 of repositories for wafuwafu13 fetched.
# Page 2 of repositories for yannickgloster fetched.
# Page 2 of repositories for odarbelaeze fetched.
# Page 3 of repositories for odarbelaeze fetched.
# Page 2 of repositories for MuZhou233 fetched.
# Page 2 of repositories for gary-rafferty fetched.
# Page 2 of repositories for arturmartins fetched.
# Page 2 of repositories for henriqueconte fetched.
# Page 2 of repositories for codingedward fetched.
# Page 2 of repositories for LukeHackett12 fetched.
# Page 2 of repositories for paulmcquad fetched.
# Page 3 of repositories for paulmcquad fetched.
# Page 2 of repositories for shanecurran fetched.
# Page 2 of repositories for jamesperes-zz fetched.
# Page 2 of repositories for iKristy fetched.
# Page 2 of repositories for yigitv4rli fetched.
# Page 2 of repositories for rafapages fetched.
# Page 2 of repositories for Char1esOrz fetched.
# Page 2 of repositories for goyox86 fetched.
# Page 3 of repositories for goyox86 fetched.
# Page 2 of repositories for LucasReinaldo fetched.
# Page 2 of repositories for coheigea fetched.
# Page 2 of repositories for blai fetched.
# Page 2 of repositories for lexesj fetched.
# Page 2 of repositories for MerrionComputing fetched.
# Page 2 of repositories for alxrm fetched.
# Page 2 of repositories for mariodruiz fetched.
# Page 2 of repositories for luben fetched.
# Page 2 of repositories for regismesquita fetched.
# Page 2 of repositories for steveire fetched.
# Page 2 of repositories for kesbeast23 fetched.
# Page 2 of repositories for alediaferia fetched.
# Page 2 of repositories for agiuliano fetched.
# Page 2 of repositories for 22a fetched.
# Page 3 of repositories for 22a fetched.
# Page 2 of repositories for ChrisHegarty fetched.
# Page 2 of repositories for Brian1KB fetched.
# Page 2 of repositories for taebow fetched.
# Page 2 of repositories for mtrovo fetched.
# Page 2 of repositories for gytdau fetched.
# Page 2 of repositories for gdyrrahitis fetched.
# Page 2 of repositories for ivucica fetched.
# Page 2 of repositories for devplayer0 fetched.
# Page 2 of repositories for 5olitude fetched.
# Page 2 of repositories for frcs fetched.
# Page 2 of repositories for OganBelema fetched.
# Page 3 of repositories for OganBelema fetched.
# Page 2 of repositories for rebeccatraceyt fetched.
# Page 2 of repositories for sentinelleader fetched.
# Page 3 of repositories for sentinelleader fetched.
# Page 2 of repositories for igor-elovikov fetched.
# Page 2 of repositories for Cryt-Software fetched.
# Page 2 of repositories for decmurphy fetched.
# Page 2 of repositories for vishwakarma fetched.
# Page 2 of repositories for gagern fetched.
# Page 3 of repositories for gagern fetched.
# Page 2 of repositories for rohanjaswal2507 fetched.
# Page 2 of repositories for ismisepaul fetched.
# Page 2 of repositories for Madjda fetched.
# Page 2 of repositories for scottire fetched.
# Page 2 of repositories for juannunesz fetched.
# Page 2 of repositories for apassant fetched.
# Page 2 of repositories for gustavomagella fetched.
# Page 2 of repositories for kenguest fetched.
# Page 2 of repositories for jaksi fetched.
# Page 2 of repositories for kastwey fetched.
# Page 2 of repositories for l-bat fetched.
# Page 2 of repositories for pinkishincoloragain fetched.
# Page 2 of repositories for chico fetched.
# Page 2 of repositories for benkelly fetched.
# Page 2 of repositories for marcustut fetched.
# Page 2 of repositories for Alantrivandrum fetched.
# Page 2 of repositories for pedrotcaraujo fetched.
# Page 2 of repositories for chekoduadarsh fetched.
# Page 2 of repositories for mainkoon81 fetched.
# Page 2 of repositories for thibaud-rohmer fetched.
# Page 2 of repositories for esjmb fetched.
# Page 2 of repositories for briandipalma fetched.
# Page 3 of repositories for briandipalma fetched.
# Page 2 of repositories for ciaranlee fetched.
# Page 2 of repositories for izifortune fetched.
# Page 3 of repositories for izifortune fetched.
# Page 2 of repositories for Necior fetched.
# Page 2 of repositories for allentv fetched.
# Page 2 of repositories for skilbjo fetched.
# Page 3 of repositories for skilbjo fetched.
# Page 2 of repositories for alan-maguire fetched.
# Page 2 of repositories for alexandremalavasi fetched.
# Page 2 of repositories for Patrick160893 fetched.
# Page 2 of repositories for adrian fetched.
# Page 2 of repositories for realshaunoneill fetched.
# Page 2 of repositories for tannineo fetched.
# Page 3 of repositories for tannineo fetched.
# Page 2 of repositories for jaimebuelta fetched.
# Page 2 of repositories for cioban fetched.
# Page 2 of repositories for prakhargurawa fetched.
# Page 2 of repositories for matheuscscp fetched.
# Page 2 of repositories for jscrane fetched.
# Page 2 of repositories for maxigimenez fetched.
# Page 2 of repositories for gunerkaanalkim fetched.
# Page 2 of repositories for hmarques98 fetched.
# Page 2 of repositories for duairc fetched.
# Page 2 of repositories for prakashjha18 fetched.
# Page 2 of repositories for fthzkrtn fetched.
# Page 3 of repositories for fthzkrtn fetched.
# Page 2 of repositories for mickcrosse fetched.
# Page 2 of repositories for hakanu fetched.
# Page 2 of repositories for salyh fetched.
# Page 3 of repositories for salyh fetched.
# Page 2 of repositories for hieunguyenm fetched.
# Page 2 of repositories for ciaranpflanagan fetched.
# Page 2 of repositories for xfontes42 fetched.
# Page 2 of repositories for stuartchaney fetched.
# Page 2 of repositories for metapredicate fetched.
# Page 2 of repositories for markoshorro fetched.
# Page 2 of repositories for patrickjquinn fetched.
# Page 2 of repositories for 10xOXR fetched.
# Page 2 of repositories for BlueLort fetched.
# Page 2 of repositories for flaree fetched.
# Page 2 of repositories for CarolinaCobo fetched.
# Page 2 of repositories for jdrumgoole fetched.
# Page 2 of repositories for gagomes fetched.
# Page 2 of repositories for nakitamccool fetched.
# User data saved to users.csv
# Repository data saved to repositories.csv

# %%
import pandas as pd

def preview_data(users_file, repos_file):
    # Load the CSV files into DataFrames
    users_df = pd.read_csv(users_file)
    repos_df = pd.read_csv(repos_file)

    # Display information about users.csv
    print("Preview of users.csv:")
    print(users_df.head())  # Show first 5 rows
    print("\nData types in users.csv:")
    print(users_df.dtypes)  # Show column data types
    print("\nNumber of rows and columns in users.csv:", users_df.shape)
    print("=" * 40)  # Separator for readability

    # Display information about repositories.csv
    print("Preview of repositories.csv:")
    print(repos_df.head())  # Show first 5 rows
    print("\nData types in repositories.csv:")
    print(repos_df.dtypes)  # Show column data types
    print("\nNumber of rows and columns in repositories.csv:", repos_df.shape)
    print("=" * 40)

    # Check for missing values in each file
    print("Missing values in users.csv:")
    print(users_df.isnull().sum())
    print("\nMissing values in repositories.csv:")
    print(repos_df.isnull().sum())

if __name__ == '__main__':
    users_file = 'users.csv'  # Path to your users.csv file
    repos_file = 'repositories.csv'  # Path to your repositories.csv file
    preview_data(users_file, repos_file)
# Out:
# Preview of users.csv:
#                   login                    name  \
# 0                  orta             Orta Therox
# 1         jeromeetienne          Jerome Etienne
# 2            jonataslaw            Jonny Borges
# 3  steventroughtonsmith  Steven Troughton-Smith
# 4                  axic        Alex Beregszaszi
#
#                                    company  \
# 0                                      NaN
# 1                   MAKING WEBAR A REALITY
# 2                                     IRIS
# 3                    HIGH CAFFEINE CONTENT
# 4  ETHEREUM @IPSILON @SPEARBIT @ETHEREUMJS
#
#                                        location                     email  \
# 0  Huddersfield / NYC / Dublin / Rio de Janeiro               git@orta.io
# 1                               Dublin, Ireland  jerome.etienne@gmail.com
# 2                               Dublin, Ireland                       NaN
# 3                               Dublin, Ireland                       NaN
# 4                               Dublin, Ireland                       NaN
#
#   hireable                                                bio  public_repos  \
# 0     none  Tech on @puzzmo-com \r\n\r\nEx-TypeScript. Con...           952
# 1     true  Making WebAR a reality - Around Javascript and...           301
# 2     true  VP of Engineering from Iris Finance.\r\nDevelo...           272
# 3     none                                                NaN            98
# 4     true  Works on decentralised stuff.\r\n\r\neipnft:ax...           144
#
#    followers  following            created_at
# 0       6018        109  2009-01-24T20:40:31Z
# 1       2781         15  2010-04-26T11:58:29Z
# 2       2693         17  2018-01-23T19:17:15Z
# 3       1986          4  2009-01-08T23:51:31Z
# 4       1807          5  2008-08-11T23:38:10Z
#
# Data types in users.csv:
# login           object
# name            object
# company         object
# location        object
# email           object
# hireable        object
# bio             object
# public_repos     int64
# followers        int64
# following        int64
# created_at      object
# dtype: object
#
# Number of rows and columns in users.csv: (477, 11)
# ========================================
# Preview of repositories.csv:
#   login                     full_name            created_at  stargazers_count  \
# 0  orta       orta/11ty-twoslash-test  2020-08-23T10:48:14Z                 1
# 1  orta                    orta/31465  2020-03-24T21:00:15Z                 2
# 2  orta                    orta/31859  2020-07-14T19:02:11Z                 0
# 3  orta                        orta/a  2018-01-30T15:41:33Z                 1
# 4  orta  orta/ABetterPlaceForTweetbot  2021-12-13T05:37:20Z                 0
#
#    watchers_count    language  has_projects  has_wiki license_name
# 0               1        HTML          True      True          NaN
# 1               2  TypeScript          True      True          NaN
# 2               0  TypeScript          True      True          NaN
# 3               1  TypeScript          True      True          mit
# 4               0         NaN          True      True          mit
#
# Data types in repositories.csv:
# login               object
# full_name           object
# created_at          object
# stargazers_count     int64
# watchers_count       int64
# language            object
# has_projects          bool
# has_wiki              bool
# license_name        object
# dtype: object
#
# Number of rows and columns in repositories.csv: (29251, 9)
# ========================================
# Missing values in users.csv:
# login             0
# name              7
# company         162
# location          0
# email           241
# hireable          0
# bio             152
# public_repos      0
# followers         0
# following         0
# created_at        0
# dtype: int64
#
# Missing values in repositories.csv:
# login                   0
# full_name               0
# created_at              0
# stargazers_count        0
# watchers_count          0
# language             7247
# has_projects            0
# has_wiki                0
# license_name        14026
# dtype: int64

# %% [markdown]
# Q1: Who are the top 5 users in Dublin with the highest number of followers? List their login in order, comma-separated.
# Users

# %%
import pandas as pd

# Load the users data from the CSV file
users_df = pd.read_csv('users.csv')

# Filter users based in Dublin
dublin_users = users_df[users_df['location'].str.contains('Dublin', na=False)]

# Sort by number of followers in descending order and select the top 5
top_dublin_users = dublin_users.sort_values(by='followers', ascending=False).head(5)

# Get the login names of the top 5 users
top_logins = top_dublin_users['login'].tolist()

# Join the logins into a comma-separated string
result = ','.join(top_logins)

# Output the result
print("Top 5 users in Dublin with the highest number of followers:")
print(result)
# Out:
# Top 5 users in Dublin with the highest number of followers:
# orta,jeromeetienne,jonataslaw,steventroughtonsmith,axic

# %% [markdown]
# Q2: Who are the 5 earliest registered GitHub users in Dublin? List their login in ascending order of created_at, comma-separated.
# Users

# %%
import csv
from datetime import datetime

# Define the list to store users from Dublin
users_in_dublin = []

# Read the CSV file with UTF-8 encoding
with open('users.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    for row in reader:
        location = row['location'].strip().lower()
        # Check if the user is from Dublin
        if 'dublin' in location:
            users_in_dublin.append({
                'login': row['login'],
                'created_at': datetime.strptime(row['created_at'], '%Y-%m-%dT%H:%M:%SZ')
            })

# Sort users based on created_at in ascending order
sorted_users = sorted(users_in_dublin, key=lambda x: x['created_at'])

# Extract the top 5 earliest user logins
top_5_earliest_logins = [user['login'] for user in sorted_users[:5]]

# Print the result as a comma-separated list
print(','.join(top_5_earliest_logins))
# Out:
# paulca,adrian,GavinJoyce,amir,ciaranlee

# %% [markdown]
# Q3: What are the 3 most popular license among these users? Ignore missing licenses. List the license_name in order, comma-separated.
# Licenses

# %%
import csv
from collections import Counter

# List to store license names
licenses = []

# Open the CSV file with UTF-8 encoding
with open('repositories.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    for row in reader:
        # Get license_name, ignoring any missing or empty entries
        license_name = row.get('license_name', '').strip()
        if license_name:
            licenses.append(license_name)

# Count the occurrence of each license
license_counts = Counter(licenses)

# Find the 3 most common licenses
top_3_licenses = [license for license, _ in license_counts.most_common(3)]

# Print the result as a comma-separated list
print(','.join(top_3_licenses))
# Out:
# mit,apache-2.0,other

# %% [markdown]
# Q4: Which company do the majority of these developers work at?
# Company (cleaned up as explained above)

# %%
import csv
from collections import Counter

# List to store company names
companies = []

# Open the CSV file with UTF-8 encoding
with open('users.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    for row in reader:
        # Get and clean up the company field (ignore empty values)
        company = row.get('company', '').strip()
        if company:
            companies.append(company)

# Count occurrences of each company
company_counts = Counter(companies)

# Identify the company with the highest count (most employees)
most_common_company = company_counts.most_common(1)

# Print the result
if most_common_company:
    print(most_common_company[0][0])  # Print only the company name
else:
    print("No company data found.")
# Out:
# MICROSOFT

# %% [markdown]
# Q5: Which programming language is most popular among these users?
# Language

# %%
import csv
from collections import Counter

# List to store programming languages
languages = []

# Open the CSV file with UTF-8 encoding
with open('repositories.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    for row in reader:
        # Get and clean up the language field (ignore empty values)
        language = row.get('language', '').strip()
        if language:
            languages.append(language)

# Count occurrences of each language
language_counts = Counter(languages)

# Find the most common language
most_common_language = language_counts.most_common(1)

# Print the result
if most_common_language:
    print(most_common_language[0][0])  # Print only the language name
else:
    print("No language data found.")
# Out:
# JavaScript

# %% [markdown]
# Q6: Which programming language is the second most popular among users who joined after 2020?
# Language

# %%
import csv
from collections import Counter
from datetime import datetime

# List to store programming languages of users who joined after 2020
languages = []

# Open the CSV file with UTF-8 encoding
with open('repositories.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)

    # Iterate through each row in the CSV
    for row in reader:
        # Parse the created_at field and check the join date
        created_at = row.get('created_at', '').strip()
        if created_at:
            user_join_date = datetime.strptime(created_at, "%Y-%m-%dT%H:%M:%SZ")

            # Check if the user joined after 2020
            if user_join_date.year > 2020:
                # Get and clean the language field
                language = row.get('language', '').strip()
                if language:
                    languages.append(language)

# Count occurrences of each language
language_counts = Counter(languages)

# Find the two most common languages
most_common_languages = language_counts.most_common(2)

# Print the second most common language
if len(most_common_languages) >= 2:
    print(most_common_languages[1][0])  # Second most common language
else:
    print("Not enough language data found.")
# Out:
# Python

# %% [markdown]
# Q7: Which language has the highest average number of stars per repository?
# Language

# %%
import csv
from collections import defaultdict

# Dictionary to store total stars and repository count per language
language_stats = defaultdict(lambda: {'stars': 0, 'repos': 0})

# Read the CSV file with UTF-8 encoding
with open('repositories.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)

    for row in reader:
        # Get the language and stargazers_count fields
        language = row.get('language', '').strip()
        stars = row.get('stargazers_count', '0').strip()

        # Only process if language and stars are available and stars are numeric
        if language and stars.isdigit():
            language_stats[language]['stars'] += int(stars)
            language_stats[language]['repos'] += 1

# Calculate the average stars per repository for each language
average_stars_per_language = {
    language: stats['stars'] / stats['repos']
    for language, stats in language_stats.items()
    if stats['repos'] > 0
}

# Find the language with the highest average stars
if average_stars_per_language:
    most_popular_language = max(average_stars_per_language, key=average_stars_per_language.get)
    print(most_popular_language)
else:
    print("No language data found.")
# Out:
# MDX

# %% [markdown]
# Q8: Let's define leader_strength as followers / (1 + following). Who are the top 5 in terms of leader_strength? List their login in order, comma-separated.
# User login

# %%
import csv

# List to store users and their leader strength
leader_strengths = []

# Read the CSV file with UTF-8 encoding
with open('users.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)

    for row in reader:
        # Get followers and following counts, converting them to integers
        followers = int(row.get('followers', '0').strip())
        following = int(row.get('following', '0').strip())

        # Calculate leader strength
        leader_strength = followers / (1 + following)

        # Store the user's login and their leader strength
        leader_strengths.append((row.get('login', '').strip(), leader_strength))

# Sort users by leader strength in descending order
leader_strengths.sort(key=lambda x: x[1], reverse=True)

# Get the top 5 users
top_5_leaders = [login for login, strength in leader_strengths[:5]]

# Print the result as a comma-separated list
print(','.join(top_5_leaders))
# Out:
# flaviohenriquealmeida,zalando,AnikSarker,wix,CardinalHealth

# %% [markdown]
# Q9: What is the correlation between the number of followers and the number of public repositories among users in Dublin?
# Correlation between followers and repos (to 3 decimal places, e.g. 0.123 or -0.123)

# %%
import csv
import numpy as np

# Lists to store the followers and public repos of users from Dublin
followers = []
public_repos = []

# Open the users.csv file and read data
with open('users.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)

    for row in reader:
        # Filter for users in Dublin
        location = row.get('location', '').strip().lower()
        if "dublin" in location:
            # Get followers and public repositories values
            try:
                followers_count = int(row['followers'])
                public_repos_count = int(row['public_repos'])

                # Append the valid values to the lists
                followers.append(followers_count)
                public_repos.append(public_repos_count)
            except ValueError:
                # Skip rows with invalid numerical values
                continue

# Ensure there is data to compute correlation
if len(followers) > 1 and len(public_repos) > 1:
    # Compute Pearson correlation coefficient
    correlation_matrix = np.corrcoef(followers, public_repos)
    correlation = correlation_matrix[0, 1]
    # Output correlation rounded to 3 decimal places
    print(f"{correlation:.3f}")
else:
    print("Insufficient data for correlation calculation.")
# Out:
# 0.556

# %% [markdown]
# Q10: Does creating more repos help users get more followers? Using regression, estimate how many additional followers a user gets per additional public repository.
# Regression slope of followers on repos (to 3 decimal places, e.g. 0.123 or -0.123)

# %%
import csv
import numpy as np

# Lists to store the followers and public repos of users
followers = []
public_repos = []

# Open the users.csv file and read data
with open('users.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)

    for row in reader:
        # Get followers and public repositories values
        try:
            followers_count = int(row['followers'])
            public_repos_count = int(row['public_repos'])

            # Append the valid values to the lists
            followers.append(followers_count)
            public_repos.append(public_repos_count)
        except ValueError:
            # Skip rows with invalid numerical values
            continue

# Ensure there is data for regression
if len(followers) > 1 and len(public_repos) > 1:
    # Perform linear regression: followers ~ public_repos
    slope, intercept = np.polyfit(public_repos, followers, 1)

    # Output the slope rounded to 3 decimal places
    print(f"{slope:.3f}")
else:
    print("Insufficient data for regression.")
# Out:
# 2.834

# %% [markdown]
# Q11: Do people typically enable projects and wikis together? What is the correlation between a repo having projects enabled and having wiki enabled?
# Correlation between projects and wiki enabled (to 3 decimal places, e.g. 0.123 or -0.123)

# %%
import pandas as pd
import numpy as np

def analyze_repo_features(csv_file):
    # Read the CSV file into a DataFrame
    df = pd.read_csv(csv_file)

    # Convert 'has_projects' and 'has_wiki' columns to boolean if they are strings
    if df['has_projects'].dtype == 'object':
        df['has_projects'] = df['has_projects'].map({'true': True, 'false': False})
    if df['has_wiki'].dtype == 'object':
        df['has_wiki'] = df['has_wiki'].map({'true': True, 'false': False})

    # Calculate the correlation between projects and wiki features
    correlation = df['has_projects'].corr(df['has_wiki'])

    # Calculate additional statistics
    stats = {
        'total_repos': len(df),
        'projects_enabled': df['has_projects'].sum(),
        'wiki_enabled': df['has_wiki'].sum(),
        'both_enabled': ((df['has_projects']) & (df['has_wiki'])).sum(),
        'neither_enabled': ((~df['has_projects']) & (~df['has_wiki'])).sum()
    }

    return round(correlation, 3), stats

# Run the analysis function
correlation, stats = analyze_repo_features('repositories.csv')
print(f"Correlation coefficient: {correlation}")
print("\nAdditional Statistics:")
for key, value in stats.items():
    print(f"{key}: {value}")
# Out:
# Correlation coefficient: 0.315
#
# Additional Statistics:
# total_repos: 29251
# projects_enabled: 28697
# wiki_enabled: 25045
# both_enabled: 25011
# neither_enabled: 520

# %% [markdown]
# Q12: Do hireable users follow more people than those who are not hireable?
# Average of following per user for hireable=true minus the average following for the rest (to 3 decimal places, e.g. 12.345 or -12.345)

# %%
import pandas as pd

def analyze_following_difference(users_csv_path='users.csv'):
    # Read the data
    df = pd.read_csv(users_csv_path)

    # Calculate average following for hireable users
    hireable_following = df[df['hireable'] == True]['following'].mean()

    # Calculate average following for non-hireable users
    non_hireable_following = df[df['hireable'] != True]['following'].mean()

    # Calculate the difference rounded to 3 decimal places
    difference = round(hireable_following - non_hireable_following, 3)

    # Print debug information
    print(f"Number of hireable users: {len(df[df['hireable'] == True])}")
    print(f"Number of non-hireable users: {len(df[df['hireable'] != True])}")
    print(f"Average following for hireable users: {hireable_following:.3f}")
    print(f"Average following for non-hireable users: {non_hireable_following:.3f}")

    return difference

# Calculate the difference
result = analyze_following_difference()
print(f"\nDifference in average following: {result:.3f}")
# Out:
# Number of hireable users: 0
# Number of non-hireable users: 477
# Average following for hireable users: nan
# Average following for non-hireable users: 83.631
#
# Difference in average following: nan

# %% [markdown]
# Q13: Some developers write long bios. Does that help them get more followers? What's the impact of the length of their bio (in Unicode words, split by whitespace) with followers? (Ignore people without bios)
# Regression slope of followers on bio word count (to 3 decimal places, e.g. 12.345 or -12.345)

# %%
import pandas as pd
import statsmodels.api as sm

def analyze_bio_impact_on_followers(csv_file='users.csv'):
    # Load the CSV into a DataFrame
    df = pd.read_csv(csv_file)

    # Filter out users without bios
    df = df[df['bio'].notnull()]

    # Calculate the length of each bio in words (splitting by whitespace)
    df['bio_word_count'] = df['bio'].str.split().str.len()

    # Prepare the independent variable (X) and dependent variable (y)
    X = df['bio_word_count']
    y = df['followers']  # Adjust the column name as per your dataset if needed

    # Add a constant to the independent variable (for the intercept)
    X = sm.add_constant(X)

    # Fit the regression model
    model = sm.OLS(y, X).fit()

    # Get the slope (coefficient of the bio_word_count)
    slope = model.params['bio_word_count']

    # Print the regression slope rounded to three decimal places
    print(f"\nRegression slope of followers on bio word count: {slope:.3f}")

# Run the analysis
analyze_bio_impact_on_followers()
# Out:
# Regression slope of followers on bio word count: 7.550

# %% [markdown]
# Q14: Who created the most repositories on weekends (UTC)? List the top 5 users' login in order, comma-separated
# Users login

# %%
import csv
from collections import Counter
from datetime import datetime

# Counter to store the number of repositories created by each user on weekends
weekend_repo_counts = Counter()

# Open the repositories.csv file and read data
with open('repositories.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)

    for row in reader:
        created_at = row.get('created_at', '')
        user_login = row.get('login', '')  # Get the user's login

        if created_at and user_login:  # Ensure both fields are present
            # Convert created_at string to a datetime object (in UTC)
            created_date = datetime.fromisoformat(created_at[:-1])  # Remove 'Z' and convert

            # Check if the day is Saturday (5) or Sunday (6)
            if created_date.weekday() in [5, 6]:
                weekend_repo_counts[user_login] += 1  # Increment the count for the user

# Get the top 5 users who created the most repositories on weekends
top_users = weekend_repo_counts.most_common(5)

# Extract the logins of the top users
top_logins = [user[0] for user in top_users]

# Output the top users' logins as a comma-separated string
print(','.join(top_logins))
# Out:
# orta,joshuacassidy,No9,wafuwafu13,lmammino

# %% [markdown]
# Q15: Do people who are hireable share their email addresses more often?
# [fraction of users with email when hireable=true] minus [fraction of users with email for the rest] (to 3 decimal places, e.g. 0.123 or -0.123)

# %%
import pandas as pd

def analyze_email_sharing(users_csv_path='users.csv'):
    # Read the complete CSV file
    df = pd.read_csv(users_csv_path)

    # Convert email column to boolean (True if email exists, False if NaN or empty)
    df['has_email'] = df['email'].notna() & (df['email'] != '')

    # Calculate the fraction of hireable users who share their email
    hireable_mask = df['hireable'] == True
    if hireable_mask.any():
        hireable_email_fraction = df[hireable_mask]['has_email'].mean()
    else:
        hireable_email_fraction = 0

    # Calculate the fraction of non-hireable users who share their email
    non_hireable_mask = df['hireable'] != True
    if non_hireable_mask.any():
        non_hireable_email_fraction = df[non_hireable_mask]['has_email'].mean()
    else:
        non_hireable_email_fraction = 0

    # Calculate difference and round to 3 decimal places
    difference = round(hireable_email_fraction - non_hireable_email_fraction, 3)

    # Print debug information
    print(f"Total users: {len(df)}")
    print(f"Hireable users with email: {df[hireable_mask]['has_email'].sum()}/{hireable_mask.sum()}")
    print(f"Non-hireable users with email: {df[non_hireable_mask]['has_email'].sum()}/{non_hireable_mask.sum()}")
    print(f"Hireable fraction: {hireable_email_fraction:.3f}")
    print(f"Non-hireable fraction: {non_hireable_email_fraction:.3f}")

    return difference

# Read and analyze the complete dataset
result = analyze_email_sharing()
print(f"\nDifference in email sharing fraction: {result:.3f}")
# Out:
# Total users: 477
# Hireable users with email: 0/0
# Non-hireable users with email: 236/477
# Hireable fraction: 0.000
# Non-hireable fraction: 0.495
#
# Difference in email sharing fraction: -0.495

# %% [markdown]
# Q16: Let's assume that the last word in a user's name is their surname (ignore missing names, trim and split by whitespace.) What's the most common surname? (If there's a tie, list them all, comma-separated, alphabetically)
# Most common surname(s)

# %%
import csv
from collections import Counter

# Counter to store surname frequencies
surname_counter = Counter()

# Open the users.csv file and read data
with open('users.csv', 'r', encoding='utf-8') as file:
    reader = csv.DictReader(file)

    for row in reader:
        name = row.get('name', '').strip()
        if name:  # Ignore missing names
            # Split the name by whitespace and get the last word as the surname
            surname = name.split()[-1]
            surname_counter[surname] += 1

# Find the maximum frequency of surnames
if surname_counter:
    max_count = max(surname_counter.values())
    # Get all surnames with the maximum frequency
    most_common_surnames = [surname for surname, count in surname_counter.items() if count == max_count]
    # Sort surnames alphabetically
    most_common_surnames.sort()
    # Output the result
    print(f"{','.join(most_common_surnames)}: {max_count}")
else:
    print("No names found.")
# Out:
# Chen,Kenny,O'Sullivan,Quinn: 3
